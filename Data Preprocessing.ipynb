# %%
import json
import os
import pandas as pd

# %%
# Define the directory path for saving CSV files
output_dir = 'src/data/csv/'

# Create the directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# %%
# Load the data from the JSON files
with open('src/data/json/characters.json', 'r', encoding='utf-8') as file:
    characters_data = json.load(file)[0]

with open('src/data/json/chapters.json', 'r', encoding='utf-8') as file:
    chapters_data = json.load(file)

# %%
characters = []

# Extract the data for each character
for character_key, character_value in characters_data.get('humans', {}).items():
    character = {'id': character_key, **character_value}
    characters.append(character)

# Convert the data to a DataFrame
characters_df = pd.DataFrame(characters)

# Save the data to a CSV file
characters_df.to_csv(output_dir + 'characters_test.csv', index=False)
characters_df.head()
# Out:
#                                     id             name  \
# 0                    Aegon I Targaryen  Aegon Targaryen
# 1                   Aegon II Targaryen  Aegon Targaryen
# 2     Aegon Targaryen (son of Rhaegar)  Aegon Targaryen
# 3    Aemon Targaryen (son of Maekar I)  Aemon Targaryen
# 4  Aemon Targaryen (son of Viserys II)  Aemon Targaryen
#
#                                            alias(es) gender  \
# 0  [{'book': 'A Game of Thrones', 'chapter': 3, '...   Male
# 1  [{'book': 'A Game of Thrones', 'chapter': 0, '...   Male
# 2  [{'book': 'A Clash of Kings', 'chapter': 48, '...   Male
# 3  [{'book': 'A Game of Thrones', 'chapter': 0, '...   Male
# 4  [{'book': 'A Game of Thrones', 'chapter': 0, '...   Male
#
#                                             house(s)  \
# 0  [{'book': 'A Game of Thrones', 'chapter': 0, '...
# 1  [{'book': 'A Game of Thrones', 'chapter': 0, '...
# 2  [{'book': 'A Game of Thrones', 'chapter': 0, '...
# 3  [{'book': 'A Game of Thrones', 'chapter': 0, '...
# 4  [{'book': 'A Game of Thrones', 'chapter': 0, '...
#
#                                        allegiance(s)  \
# 0                                               None
# 1                                               None
# 2  [{'book': 'A Game of Thrones', 'chapter': 0, '...
# 3  [{'book': 'A Game of Thrones', 'chapter': 0, '...
# 4  [{'book': 'A Game of Thrones', 'chapter': 0, '...
#
#                                             title(s)  \
# 0  [{'book': 'A Game of Thrones', 'chapter': 0, '...
# 1  [{'book': 'A Game of Thrones', 'chapter': 0, '...
# 2  [{'book': 'A Game of Thrones', 'chapter': 0, '...
# 3  [{'book': None, 'chapter': None, 'title': 'Mae...
# 4  [{'book': 'A Game of Thrones', 'chapter': 0, '...
#
#                                               family      race  \
# 0  {'father': 'Aerion Targaryen (son of Daemion)'...  Valyrian
# 1  {'father': 'Viserys I Targaryen', 'mother': 'A...  Valyrian
# 2  {'father': 'Rhaegar Targaryen', 'mother': 'Eli...  Valyrian
# 3  {'father': 'Maekar I Targaryen', 'mother': 'Dy...  Valyrian
# 4  {'father': 'Viserys II Targaryen', 'mother': '...  Valyrian
#
#                                           culture(s)            religion  \
# 0  [{'book': 'A Game of Thrones', 'chapter': 0, '...  Faith of the Seven
# 1  [{'book': 'A Game of Thrones', 'chapter': 0, '...  Faith of the Seven
# 2  [{'book': 'A Game of Thrones', 'chapter': 0, '...                None
# 3  [{'book': 'A Game of Thrones', 'chapter': 0, '...  Faith of the Seven
# 4  [{'book': 'A Game of Thrones', 'chapter': 0, '...  Faith of the Seven
#
#                                 physical description  \
# 0  {'eye color': 'Purple', 'hair color': 'Silver-...
# 1  {'eye color': 'Violet', 'hair color': 'Silver-...
# 2  {'eye color': 'Purple', 'hair color': 'Silver-...
# 3  {'eye color': 'Milk white', 'hair color': 'Whi...
# 4  {'eye color': 'Purple', 'hair color': 'Silver-...
#
#                                                birth  \
# 0  {'continent': 'Westeros', 'region': 'Crownland...
# 1  {'continent': 'Westeros', 'region': 'The Crown...
# 2  {'continent': 'Westeros', 'region': 'Crownland...
# 3  {'continent': 'Westeros', 'region': 'The Crown...
# 4  {'continent': 'Westeros', 'region': 'The Crown...
#
#                                                death first appearance  \
# 0  {'continent': 'Westeros', 'region': 'The Crown...             None
# 1  {'continent': 'Westeros', 'region': 'The Crown...             None
# 2  {'continent': 'Westeros', 'region': 'The Crown...             None
# 3  {'continent': 'Westeros', 'region': 'The Crown...             None
# 4  {'continent': None, 'region': None, 'location'...             None
#
#   last appearance
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None

# %%
def flatten_or_none(nested_lists):
    flat = []

    def recurse(items):
        if items:
            for item in items:
                if isinstance(item, list):
                    recurse(item)
                elif item is not None:
                    flat.append(item)
    
    recurse(nested_lists)

    return flat if flat else None

def extract_values(item, key):
    """
    Extracts values associated with a specific key from a list of dictionaries or a single dictionary.
    
    Parameters:
    - item: The input data, which can be a list of dictionaries, a single dictionary, or another type.
    - key: The key whose associated values need to be extracted.
    
    Returns:
    - A list of extracted values if the input is a list of dictionaries.
    - A single value if the input is a dictionary.
    - The original item if it's neither a list nor a dictionary.
    """
    if not item:
        return None

    if isinstance(key, tuple):
        if isinstance(item, list):
            return flatten_or_none([extract_values(element.get(key[0]), key[1]) if isinstance(element, dict) else element for element in item])
    
        if isinstance(item, dict):
            return extract_values(item.get(key[0]), key[1])
    
    if isinstance(key, str):
        if isinstance(item, list):
            return flatten_or_none([element.get(key) if isinstance(element, dict) else element for element in item])
    
        if isinstance(item, dict):
            return item.get(key)
    
    if isinstance(key, list):
        results = []
        for k in key:
            results.append(extract_values(item, k))

        return flatten_or_none(results)

def replace_columns(df, old_col, new_cols):
    """
    Replaces an existing column with multiple new columns while preserving the column order.
    
    Parameters:
    - df: The pandas DataFrame.
    - old_col: The name of the column to be replaced.
    - new_cols: A dictionary where keys are new column names and values are the data for these columns.
    
    Returns:
    - None. The DataFrame is modified in place.
    """
    if old_col not in df.columns:
        return
    # Get the index of the column to be replaced
    col_idx = df.columns.get_loc(old_col)
    # Drop the old column
    df.drop(columns=[old_col], inplace=True)
    # Insert each new column at the correct position
    for i, (new_col, data) in enumerate(new_cols.items()):
        df.insert(col_idx + i, new_col, data)

display(characters_df.head())
# Out:
#                                     id             name  \
# 0                    Aegon I Targaryen  Aegon Targaryen
# 1                   Aegon II Targaryen  Aegon Targaryen
# 2     Aegon Targaryen (son of Rhaegar)  Aegon Targaryen
# 3    Aemon Targaryen (son of Maekar I)  Aemon Targaryen
# 4  Aemon Targaryen (son of Viserys II)  Aemon Targaryen
#
#                                            alias(es) gender  \
# 0  [{'book': 'A Game of Thrones', 'chapter': 3, '...   Male
# 1  [{'book': 'A Game of Thrones', 'chapter': 0, '...   Male
# 2  [{'book': 'A Clash of Kings', 'chapter': 48, '...   Male
# 3  [{'book': 'A Game of Thrones', 'chapter': 0, '...   Male
# 4  [{'book': 'A Game of Thrones', 'chapter': 0, '...   Male
#
#                                             house(s)  \
# 0  [{'book': 'A Game of Thrones', 'chapter': 0, '...
# 1  [{'book': 'A Game of Thrones', 'chapter': 0, '...
# 2  [{'book': 'A Game of Thrones', 'chapter': 0, '...
# 3  [{'book': 'A Game of Thrones', 'chapter': 0, '...
# 4  [{'book': 'A Game of Thrones', 'chapter': 0, '...
#
#                                        allegiance(s)  \
# 0                                               None
# 1                                               None
# 2  [{'book': 'A Game of Thrones', 'chapter': 0, '...
# 3  [{'book': 'A Game of Thrones', 'chapter': 0, '...
# 4  [{'book': 'A Game of Thrones', 'chapter': 0, '...
#
#                                             title(s)  \
# 0  [{'book': 'A Game of Thrones', 'chapter': 0, '...
# 1  [{'book': 'A Game of Thrones', 'chapter': 0, '...
# 2  [{'book': 'A Game of Thrones', 'chapter': 0, '...
# 3  [{'book': None, 'chapter': None, 'title': 'Mae...
# 4  [{'book': 'A Game of Thrones', 'chapter': 0, '...
#
#                                               family      race  \
# 0  {'father': 'Aerion Targaryen (son of Daemion)'...  Valyrian
# 1  {'father': 'Viserys I Targaryen', 'mother': 'A...  Valyrian
# 2  {'father': 'Rhaegar Targaryen', 'mother': 'Eli...  Valyrian
# 3  {'father': 'Maekar I Targaryen', 'mother': 'Dy...  Valyrian
# 4  {'father': 'Viserys II Targaryen', 'mother': '...  Valyrian
#
#                                           culture(s)            religion  \
# 0  [{'book': 'A Game of Thrones', 'chapter': 0, '...  Faith of the Seven
# 1  [{'book': 'A Game of Thrones', 'chapter': 0, '...  Faith of the Seven
# 2  [{'book': 'A Game of Thrones', 'chapter': 0, '...                None
# 3  [{'book': 'A Game of Thrones', 'chapter': 0, '...  Faith of the Seven
# 4  [{'book': 'A Game of Thrones', 'chapter': 0, '...  Faith of the Seven
#
#                                 physical description  \
# 0  {'eye color': 'Purple', 'hair color': 'Silver-...
# 1  {'eye color': 'Violet', 'hair color': 'Silver-...
# 2  {'eye color': 'Purple', 'hair color': 'Silver-...
# 3  {'eye color': 'Milk white', 'hair color': 'Whi...
# 4  {'eye color': 'Purple', 'hair color': 'Silver-...
#
#                                                birth  \
# 0  {'continent': 'Westeros', 'region': 'Crownland...
# 1  {'continent': 'Westeros', 'region': 'The Crown...
# 2  {'continent': 'Westeros', 'region': 'Crownland...
# 3  {'continent': 'Westeros', 'region': 'The Crown...
# 4  {'continent': 'Westeros', 'region': 'The Crown...
#
#                                                death first appearance  \
# 0  {'continent': 'Westeros', 'region': 'The Crown...             None
# 1  {'continent': 'Westeros', 'region': 'The Crown...             None
# 2  {'continent': 'Westeros', 'region': 'The Crown...             None
# 3  {'continent': 'Westeros', 'region': 'The Crown...             None
# 4  {'continent': None, 'region': None, 'location'...             None
#
#   last appearance
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None

# %%
characters_mapping = {
    'title(s)': 'title',
    'house(s)': 'house',
    'culture(s)': 'culture',
    'allegiance(s)': 'allegiance',
    'alias(es)': 'alias',
    'family': {
        'father': 'father',
        'mother': 'mother',
        'sibling(s)': ('sibling(s)', 'sibling'),
        'child(ren)': ('child(ren)', 'child'),
        'spouse(s)': ('spouse(s)', 'spouse'),
        'lover(s)': ('lover(s)', 'lover'),
    },
    'birth': {
        'birth_continent': 'continent',
        'birth_region': 'region',
        'birth_location': 'location',
        'birth_date': 'date'
    },
    'death': {
        'death_continent': 'continent',
        'death_region': 'region',
        'death_location': 'location',
        'death_date': 'date',
        'death_reason': ('by', 'type'),
        'killed_by': ('by', 'name')
    },
    'first appearance': {
        'first_appearance_book': 'book',
        'first_appearance_chapter': 'chapter'
    },
    'last appearance': {
        'last_appearance_book': 'book',
        'last_appearance_chapter': 'chapter'
    },
    'physical description': {
        'eye color': 'eye color',
        'hair color': 'hair color'
    }
}

# Transform location-related columns
for old_col, mappings in characters_mapping.items():
    if old_col in characters_df.columns:
        if isinstance(mappings, str):
            characters_df[old_col] = characters_df[old_col].apply(lambda x: extract_values(x, mappings))
        else:   
            new_cols = {}
            for new_col, key in mappings.items():
                new_cols[new_col] = characters_df[old_col].apply(lambda item: extract_values(item, key))
            replace_columns(characters_df, old_col, new_cols)

# Save the transformed data to a CSV file
characters_df.to_csv(output_dir + 'characters_test.csv', index=False)
characters_df.head()

# Print all the values of the first row
for col in characters_df.columns:
    print(f'{col}: {characters_df[col][0]}')
# Out:
# id: Aegon I Targaryen
# name: Aegon Targaryen
# alias(es): ['Aegon the Conqueror', 'Aegon the Dragonlord', 'Aegon Dragonlord', 'Aegon the Dragon']
# gender: Male
# house(s): ['Targaryen']
# allegiance(s): None
# title(s): ['Lord of Dragonstone', 'King of All Westeros', 'Shield of His People', 'King of the Andals, the Rhoynar, and the First Men', 'Lord of the Seven Kingdoms', 'Protector of the Realm']
# father: Aerion Targaryen (son of Daemion)
# mother: Valaena Velaryon
# sibling(s): ['Rhaenys Targaryen', 'Visenya Targaryen']
# child(ren): ['Aenys I Targaryen', 'Maegor I Targaryen']
# spouse(s): ['Visenya Targaryen', 'Rhaenys Targaryen']
# lover(s): None
# race: Valyrian
# culture(s): ['Crownlander']
# religion: Faith of the Seven
# eye color: Purple
# hair color: Silver-gold
# birth_continent: Westeros
# birth_region: Crownlands
# birth_location: Dragonstone
# birth_date: 27 BC
# death_continent: Westeros
# death_region: The Crownlands
# death_location: Dragonstone
# death_date: 37 AC
# death_reason: Nature
# killed_by: Stroke
# first_appearance_book: None
# first_appearance_chapter: nan
# last_appearance_book: None
# last_appearance_chapter: nan

# %%
chapters = []

# Extract the data for each chapter
for book in chapters_data.get('books', []):
    for chapter in book.get('chapters', {}):
        chapter = {'book_tite': book.get('title'), 'book_author': book.get('author'), 'original_version': book.get('original_version'), 'folio_society_version': book.get('folio_society_version'), **chapter}
        chapters.append(chapter)

# Convert the data to a DataFrame
chapters_df = pd.DataFrame(chapters)

# Save the data to a CSV file
chapters_df.to_csv(output_dir + 'chapters_test.csv', index=False)
chapters_df.head()
# Out:
#            book_tite          book_author  \
# 0  A Game of Thrones  George R. R. Martin
# 1  A Game of Thrones  George R. R. Martin
# 2  A Game of Thrones  George R. R. Martin
# 3  A Game of Thrones  George R. R. Martin
# 4  A Game of Thrones  George R. R. Martin
#
#                                     original_version  \
# 0  {'publication_date': '1997-08-04', 'page_count...
# 1  {'publication_date': '1997-08-04', 'page_count...
# 2  {'publication_date': '1997-08-04', 'page_count...
# 3  {'publication_date': '1997-08-04', 'page_count...
# 4  {'publication_date': '1997-08-04', 'page_count...
#
#                                folio_society_version  number       title  \
# 0  {'publication_date': '2019-07-16', 'page_count...       0    Prologue
# 1  {'publication_date': '2019-07-16', 'page_count...       1      Bran I
# 2  {'publication_date': '2019-07-16', 'page_count...       2   Catelyn I
# 3  {'publication_date': '2019-07-16', 'page_count...       3  Daenerys I
# 4  {'publication_date': '2019-07-16', 'page_count...       4    Eddard I
#
#          id                 pov                         original_counts  \
# 0  AGOT-0-0                Will  {'page_count': 11, 'word_count': None}
# 1  AGOT-0-1          Bran Stark   {'page_count': 9, 'word_count': None}
# 2  AGOT-0-2       Catelyn Stark   {'page_count': 6, 'word_count': None}
# 3  AGOT-0-3  Daenerys Targaryen  {'page_count': 11, 'word_count': None}
# 4  AGOT-0-4        Eddard Stark  {'page_count': 10, 'word_count': None}
#
#                        folio_society_counts  universe_year  \
# 0  {'page_count': None, 'word_count': None}            297
# 1  {'page_count': None, 'word_count': None}            298
# 2  {'page_count': None, 'word_count': None}            298
# 3  {'page_count': None, 'word_count': None}            298
# 4  {'page_count': None, 'word_count': None}            298
#
#                                              summary theme(s)  \
# 0  While tracking a group of wildling raiders bey...     None
# 1  Lord Eddard Stark dispenses justice to a Night...     None
# 2  Lady Catelyn Tully seeks out her husband, Lord...     None
# 3  The exiled Princess Daenerys Targaryen prepare...     None
# 4  King Robert I Baratheon arrives with his party...     None
#
#                                           characters  \
# 0  {'direwolves': None, 'humans': {'present': ['W...
# 1  {'direwolves': {'present': ['Ghost', 'Grey Win...
# 2  {'direwolves': None, 'humans': {'present': ['C...
# 3  {'direwolves': None, 'humans': {'present': ['C...
# 4  {'direwolves': None, 'humans': {'present': ['C...
#
#                                           continents  \
# 0  {'present': [{'name': 'Westeros', 'regions': {...
# 1  {'present': [{'name': 'Westeros', 'regions': {...
# 2  {'present': [{'name': 'Westeros', 'regions': {...
# 3  {'present': [{'name': 'Essos', 'regions': {'pr...
# 4  {'present': [{'name': 'Westeros', 'regions': {...
#
#                                               groups  \
# 0  {'factions': None, 'houses': {'present': ['Hou...
# 1  {'factions': None, 'houses': {'present': ['Hou...
# 2  {'factions': None, 'houses': {'present': ['Hou...
# 3  {'factions': None, 'houses': {'present': ['Hou...
# 4  {'factions': None, 'houses': {'present': ['Hou...
#
#                                               events
# 0                                               None
# 1  {'present': None, 'mentioned': [{'type': 'Peri...
# 2  {'present': None, 'mentioned': [{'type': 'Cata...
# 3  {'present': None, 'mentioned': [{'type': 'Batt...
# 4  {'present': None, 'mentioned': [{'type': 'War'...

# %%
chapters_mapping = {
    'original_version': {
        'original_book_publication_date': 'publication_date',
        'original_book_page_count': 'page_count',
        'original_book_edition': 'edition',
        'original_book_isbn': 'isbn',
        'original_book_language': 'language'
    },
    'folio_society_version': {
        'folio_society_book_publication_date': 'publication_date',
        'folio_society_book_page_count': 'page_count',
        'folio_society_book_edition': 'edition',
        'folio_society_book_isbn': 'isbn',
        'folio_society_book_language': 'language'
    },
    'original_counts': {
        'original_chapter_page_count': 'page_count',
        'original_chapter_word_count': 'word_count'
    },
    'folio_society_counts': {
        'folio_society_chapter_page_count': 'page_count',
        'folio_society_chapter_word_count': 'word_count'
    },
    'characters': {
        'present_direwolves': ('direwolves', 'present'),
        'mentioned_direwolves': ('direwolves', 'mentioned'),
        'present_humans': ('humans', 'present'),
        'mentioned_humans': ('humans', 'mentioned'),
    },
    'continents': {
        'present_continents': ('present', 'name'),
        'mentioned_continents': ('mentioned', 'name'),

        'present_regions': ('present', ('regions', ('present', 'name'))),
        'mentioned_regions': [
            ('mentioned', ('regions', ('mentioned', 'name'))),
            ('present', ('regions', ('mentioned', 'name')))
        ],

        'present_locations': ('present', ('regions', ('present', ('locations', ('present', 'name'))))),
        'mentioned_locations': [
            ('present', ('regions', ('present', ('locations', ('mentioned', 'name'))))),
            ('present', ('regions', ('mentioned', ('locations', ('mentioned', 'name'))))),
            ('mentioned', ('regions', ('mentioned', ('locations', ('mentioned', 'name'))))),
        ],
    },
    'groups': {
        'present_factions': ('factions', 'present'),
        'mentioned_factions': ('factions', 'mentioned'),

        'present_houses': ('houses', 'present'),
        'mentioned_houses': ('houses', 'mentioned'),

        'present_mercenary_companies': ('mercenary companies', 'present'),
        'mentioned_mercenary_companies': ('mercenary companies', 'mentioned'),

        'present_military_orders': ('military orders', 'present'),
        'mentioned_military_orders': ('military orders', 'mentioned'),

        'present_other_orders': ('other orders', 'present'),
        'mentioned_other_orders': ('other orders', 'mentioned'),

        'present_peoples': ('peoples', 'present'),
        'mentioned_peoples': ('peoples', 'mentioned'),

        'present_religious_orders': ('religious orders', 'present'),
        'mentioned_religious_orders': ('religious orders', 'mentioned'),
    },
    'events': {
        'present_events_types': ('present', 'type'),
        'present_events_names': ('present', 'name'),
        'mentioned_events_types': ('mentioned', 'type'),
        'mentioned_events_names': ('mentioned', 'name'),
    }
}

# Transform dictionary columns to multiple columns based on the mappings
for old_col, mappings in chapters_mapping.items():
    if old_col in chapters_df.columns:
        new_cols = {}
        for new_col, key in mappings.items():
            new_cols[new_col] = chapters_df[old_col].apply(lambda item: extract_values(item, key))
        replace_columns(chapters_df, old_col, new_cols)

# Save the transformed data to a CSV file
chapters_df.to_csv(output_dir + 'chapters_test.csv', index=False)
chapters_df.head(11)
# Out:
#             book_tite          book_author original_book_publication_date  \
# 0   A Game of Thrones  George R. R. Martin                     1997-08-04
# 1   A Game of Thrones  George R. R. Martin                     1997-08-04
# 2   A Game of Thrones  George R. R. Martin                     1997-08-04
# 3   A Game of Thrones  George R. R. Martin                     1997-08-04
# 4   A Game of Thrones  George R. R. Martin                     1997-08-04
# 5   A Game of Thrones  George R. R. Martin                     1997-08-04
# 6   A Game of Thrones  George R. R. Martin                     1997-08-04
# 7   A Game of Thrones  George R. R. Martin                     1997-08-04
# 8   A Game of Thrones  George R. R. Martin                     1997-08-04
# 9   A Game of Thrones  George R. R. Martin                     1997-08-04
# 10  A Game of Thrones  George R. R. Martin                     1997-08-04
#
#     original_book_page_count original_book_edition original_book_isbn  \
# 0                        864    Unabridged Version  978-0-553-57340-4
# 1                        864    Unabridged Version  978-0-553-57340-4
# 2                        864    Unabridged Version  978-0-553-57340-4
# 3                        864    Unabridged Version  978-0-553-57340-4
# 4                        864    Unabridged Version  978-0-553-57340-4
# 5                        864    Unabridged Version  978-0-553-57340-4
# 6                        864    Unabridged Version  978-0-553-57340-4
# 7                        864    Unabridged Version  978-0-553-57340-4
# 8                        864    Unabridged Version  978-0-553-57340-4
# 9                        864    Unabridged Version  978-0-553-57340-4
# 10                       864    Unabridged Version  978-0-553-57340-4
#
#    original_book_language folio_society_book_publication_date  \
# 0                 English                          2019-07-16
# 1                 English                          2019-07-16
# 2                 English                          2019-07-16
# 3                 English                          2019-07-16
# 4                 English                          2019-07-16
# 5                 English                          2019-07-16
# 6                 English                          2019-07-16
# 7                 English                          2019-07-16
# 8                 English                          2019-07-16
# 9                 English                          2019-07-16
# 10                English                          2019-07-16
#
#     folio_society_book_page_count folio_society_book_edition  ...  \
# 0                             824          The Folio Society  ...
# 1                             824          The Folio Society  ...
# 2                             824          The Folio Society  ...
# 3                             824          The Folio Society  ...
# 4                             824          The Folio Society  ...
# 5                             824          The Folio Society  ...
# 6                             824          The Folio Society  ...
# 7                             824          The Folio Society  ...
# 8                             824          The Folio Society  ...
# 9                             824          The Folio Society  ...
# 10                            824          The Folio Society  ...
#
#    present_other_orders mentioned_other_orders  present_peoples  \
# 0                  None             [Maesters]     [The Others]
# 1                  None                   None             None
# 2                  None             [Maesters]             None
# 3                  None                   None   [The Dothraki]
# 4                  None                   None             None
# 5                  None                   None             None
# 6            [Maesters]                   None             None
# 7                  None                   None             None
# 8                  None             [Maesters]             None
# 9                  None             [Maesters]             None
# 10                 None                   None             None
#
#                                     mentioned_peoples  \
# 0                                         [Wildlings]
# 1   [The Andals, The First Men, The Others, The Rh...
# 2   [The children of the Forest, The Others, Wildl...
# 3            [The Andals, The First Men, The Rhoynar]
# 4                                        [The Others]
# 5                                                None
# 6                                        [The Others]
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
#
#    present_religious_orders mentioned_religious_orders  present_events_types  \
# 0                      None                       None                  None
# 1                      None                       None                  None
# 2                      None                  [Septons]                  None
# 3                      None              [Red Priests]                  None
# 4                      None                       None                  None
# 5                      None                       None                  None
# 6                      None                       None                  None
# 7                      None                   [Septas]                  None
# 8                      None                       None                  None
# 9                 [Septons]                       None                  None
# 10                     None                   [Septas]                  None
#
#    present_events_names mentioned_events_types  \
# 0                  None                   None
# 1                  None               [Period]
# 2                  None            [Cataclysm]
# 3                  None    [Battle, Cataclysm]
# 4                  None                  [War]
# 5                  None                  [War]
# 6                  None                   None
# 7                  None                   None
# 8                  None                  [War]
# 9                  None                   None
# 10                 None                   None
#
#                               mentioned_events_names
# 0                                               None
# 1                                   [The Long Night]
# 2                              [The Doom of Valyria]
# 3   [The Battle of the Trident, The Doom of Valyria]
# 4                              [Greyjoy's Rebellion]
# 5                            [The Conquest of Dorne]
# 6                                               None
# 7                                               None
# 8                         [The Dance of the Dragons]
# 9                                               None
# 10                                              None
#
# [11 rows x 51 columns]

# %%
# Extraire les personnages humains mentionnés ou apparaissants dans les chapitres
mentioned_or_present_humans = set(chapters_df['present_humans'].explode().dropna().unique()).union(
    set(chapters_df['mentioned_humans'].explode().dropna().unique())
)

# Extraire les personnages présents dans le characters_df
characters_in_df = set(characters_df['id'].dropna().unique())

# Trouver les personnages humains mentionnés ou apparaissants mais pas présents dans le characters_df
missing_characters = mentioned_or_present_humans - characters_in_df

# Afficher les personnages manquants
missing_characters
# Out:
# set()

# %%
additional_characters = characters_in_df - mentioned_or_present_humans

# Afficher les personnages supplémentaires
additional_characters
# Out:
# {'Farlen', 'High Septon (fat one)'}
